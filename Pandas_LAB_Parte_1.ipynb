# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## Dataframe & Python
#
# ### LAP Parte 1: “10 minutes to pandas"
# ### Aluno: Pedro Lucas de Andrade Nunes
#
# https://pandas.pydata.org/docs/user_guide/10min.html

# %% [markdown]
# Sugestão: Colocar a página do Cookbook lado a lado com este notebook para realizar as operações.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 6.1.58+
# Version          : #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 2.0.3
# numpy            : 1.25.2
# pytz             : 2023.4
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.10
# pytest           : 7.4.4
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.4
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.9
# jinja2           : 3.1.3
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# bs4              : 4.12.3
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.6.0
# gcsfs            : 2023.6.0
# matplotlib       : 3.7.1
# numba            : 0.58.1
# numexpr          : 2.10.0
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : 0.19.2
# pyarrow          : 14.0.2
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.11.4
# snappy           : None
# sqlalchemy       : 2.0.29
# tables           : 3.8.0
# tabulate         : 0.9.0
# xarray           : 2023.7.0
# xlrd             : 2.0.1
# zstandard        : None
# tzdata           : 2024.1
# qtpy             : None
# pyqt5            : None

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554775  1.993162 -0.932593  0.273217
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826
# 2013-01-06  0.301586 -1.536680  0.390668 -1.689015

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554775  1.993162 -0.932593  0.273217
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826
# 2013-01-06  0.301586 -1.536680  0.390668 -1.689015

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.55477483,  1.9931616 , -0.93259349,  0.27321718],
#        [-0.51026109,  0.50551888, -0.79081483, -1.55790466],
#        [ 0.67753832,  2.07550507,  1.32349763, -0.20766891],
#        [ 0.84304725, -0.67070072, -0.2219764 , -1.68080962],
#        [ 0.5675856 ,  0.92721007, -0.11003366, -0.71082613],
#        [ 0.30158609, -1.53668012,  0.3906676 , -1.68901456]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.220787  0.549002 -0.056876 -0.928834
# std    0.609681  1.442115  0.829621  0.842805
# min   -0.554775 -1.536680 -0.932593 -1.689015
# 25%   -0.307299 -0.376646 -0.648605 -1.650083
# 50%    0.434586  0.716364 -0.166005 -1.134365
# 75%    0.650050  1.726674  0.265492 -0.333458
# max    0.843047  2.075505  1.323498  0.273217

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.554775   -0.510261    0.677538    0.843047    0.567586    0.301586
# B    1.993162    0.505519    2.075505   -0.670701    0.927210   -1.536680
# C   -0.932593   -0.790815    1.323498   -0.221976   -0.110034    0.390668
# D    0.273217   -1.557905   -0.207669   -1.680810   -0.710826   -1.689015

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.273217 -0.932593  1.993162 -0.554775
# 2013-01-02 -1.557905 -0.790815  0.505519 -0.510261
# 2013-01-03 -0.207669  1.323498  2.075505  0.677538
# 2013-01-04 -1.680810 -0.221976 -0.670701  0.843047
# 2013-01-05 -0.710826 -0.110034  0.927210  0.567586
# 2013-01-06 -1.689015  0.390668 -1.536680  0.301586

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-06  0.301586 -1.536680  0.390668 -1.689015
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826
# 2013-01-01 -0.554775  1.993162 -0.932593  0.273217
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669

# %%
df["A"]
# Out:
# 2013-01-01   -0.554775
# 2013-01-02   -0.510261
# 2013-01-03    0.677538
# 2013-01-04    0.843047
# 2013-01-05    0.567586
# 2013-01-06    0.301586
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554775  1.993162 -0.932593  0.273217
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669

# %%
df[1:-1]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554775  1.993162 -0.932593  0.273217
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810
# 2013-01-05  0.567586  0.927210 -0.110034 -0.710826
# 2013-01-06  0.301586 -1.536680  0.390668 -1.689015

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.510261  0.505519 -0.790815 -1.557905
# 2013-01-03  0.677538  2.075505  1.323498 -0.207669
# 2013-01-04  0.843047 -0.670701 -0.221976 -1.680810

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.774841 -1.032963 -0.648853 -0.885728
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-03 -1.663009 -0.152270 -1.249730 -0.796954
# 2013-01-04 -0.248932 -1.722477  0.572717  1.315293
# 2013-01-05  0.123981 -0.972887  1.350000  0.176672
# 2013-01-06 -0.519400 -0.269084 -0.512812 -0.863338

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.A
df2.bool
df2.abs
df2.boxplot
df2.add
df2.C
df2.add_prefix
df2.clip
df2.add_suffix
df2.columns
df2.align
df2.copy
df2.all
df2.count
df2.any
df2.combine
df2.D
df2.apply
df2.describe
df2.applymap
df2.diff
df2.B
df2.duplicated
# Out:
# <bound method DataFrame.duplicated of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df.head()
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.248932 -1.722477  0.572717  1.315293
# 2013-01-05  0.123981 -0.972887  1.350000  0.176672
# 2013-01-06 -0.519400 -0.269084 -0.512812 -0.863338

# %%
df.index
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.7748407 , -1.03296319, -0.64885339, -0.88572769],
#        [ 0.33257453, -0.42721558, -0.78853096,  1.60191106],
#        [-1.66300883, -0.15226982, -1.24973046, -0.79695369],
#        [-0.24893205, -1.72247727,  0.57271698,  1.31529295],
#        [ 0.12398133, -0.9728867 ,  1.35000018,  0.17667224],
#        [-0.51940003, -0.26908416, -0.51281228, -0.8633385 ]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.199991 -0.762816 -0.212868  0.091309
# std    0.846607  0.594512  0.974292  1.135104
# min   -1.663009 -1.722477 -1.249730 -0.885728
# 25%   -0.451783 -1.017944 -0.753612 -0.846742
# 50%   -0.062475 -0.700051 -0.580833 -0.310141
# 75%    0.280426 -0.308617  0.301335  1.030638
# max    0.774841 -0.152270  1.350000  1.601911

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.774841    0.332575   -1.663009   -0.248932    0.123981   -0.519400
# B   -1.032963   -0.427216   -0.152270   -1.722477   -0.972887   -0.269084
# C   -0.648853   -0.788531   -1.249730    0.572717    1.350000   -0.512812
# D   -0.885728    1.601911   -0.796954    1.315293    0.176672   -0.863338

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.885728 -0.648853 -1.032963  0.774841
# 2013-01-02  1.601911 -0.788531 -0.427216  0.332575
# 2013-01-03 -0.796954 -1.249730 -0.152270 -1.663009
# 2013-01-04  1.315293  0.572717 -1.722477 -0.248932
# 2013-01-05  0.176672  1.350000 -0.972887  0.123981
# 2013-01-06 -0.863338 -0.512812 -0.269084 -0.519400

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-04 -0.248932 -1.722477  0.572717  1.315293
# 2013-01-01  0.774841 -1.032963 -0.648853 -0.885728
# 2013-01-05  0.123981 -0.972887  1.350000  0.176672
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-06 -0.519400 -0.269084 -0.512812 -0.863338
# 2013-01-03 -1.663009 -0.152270 -1.249730 -0.796954

# %%
df["A"]
# Out:
# 2013-01-01    0.774841
# 2013-01-02    0.332575
# 2013-01-03   -1.663009
# 2013-01-04   -0.248932
# 2013-01-05    0.123981
# 2013-01-06   -0.519400
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.774841 -1.032963 -0.648853 -0.885728
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-03 -1.663009 -0.152270 -1.249730 -0.796954

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-03 -1.663009 -0.152270 -1.249730 -0.796954
# 2013-01-04 -0.248932 -1.722477  0.572717  1.315293

# %%
df.loc[dates[0]]
# Out:
# A    0.774841
# B   -1.032963
# C   -0.648853
# D   -0.885728
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.774841 -1.032963
# 2013-01-02  0.332575 -0.427216
# 2013-01-03 -1.663009 -0.152270
# 2013-01-04 -0.248932 -1.722477
# 2013-01-05  0.123981 -0.972887
# 2013-01-06 -0.519400 -0.269084

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.332575 -0.427216
# 2013-01-03 -1.663009 -0.152270
# 2013-01-04 -0.248932 -1.722477

# %%
df.loc[dates[0], "A"]
# Out:
# 0.7748407044910188

# %%
df.at[dates[0], "A"]
# Out:
# 0.7748407044910188

# %%
df.iloc[3]
# Out:
# A   -0.248932
# B   -1.722477
# C    0.572717
# D    1.315293
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.248932 -1.722477
# 2013-01-05  0.123981 -0.972887

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.332575 -0.788531
# 2013-01-03 -1.663009 -1.249730
# 2013-01-05  0.123981  1.350000

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-03 -1.663009 -0.152270 -1.249730 -0.796954

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.032963 -0.648853
# 2013-01-02 -0.427216 -0.788531
# 2013-01-03 -0.152270 -1.249730
# 2013-01-04 -1.722477  0.572717
# 2013-01-05 -0.972887  1.350000
# 2013-01-06 -0.269084 -0.512812

# %%
df.iloc[1, 1]
# Out:
# -0.42721558461824294

# %%
df.iat[1, 1]
# Out:
# -0.42721558461824294

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.774841 -1.032963 -0.648853 -0.885728
# 2013-01-02  0.332575 -0.427216 -0.788531  1.601911
# 2013-01-05  0.123981 -0.972887  1.350000  0.176672

# %%
df[df > 0]
# Out:
#                    A   B         C         D
# 2013-01-01  0.774841 NaN       NaN       NaN
# 2013-01-02  0.332575 NaN       NaN  1.601911
# 2013-01-03       NaN NaN       NaN       NaN
# 2013-01-04       NaN NaN  0.572717  1.315293
# 2013-01-05  0.123981 NaN  1.350000  0.176672
# 2013-01-06       NaN NaN       NaN       NaN

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B        C         D     E
# 2013-01-03 -1.663009 -0.152270 -1.24973 -0.796954   two
# 2013-01-05  0.123981 -0.972887  1.35000  0.176672  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.648853  5.0
# 2013-01-02  0.332575 -0.427216 -0.788531  5.0
# 2013-01-03 -1.663009 -0.152270 -1.249730  5.0
# 2013-01-04 -0.248932 -1.722477  0.572717  5.0
# 2013-01-05  0.123981 -0.972887  1.350000  5.0
# 2013-01-06 -0.519400 -0.269084 -0.512812  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.648853 -5.0
# 2013-01-02 -0.332575 -0.427216 -0.788531 -5.0
# 2013-01-03 -1.663009 -0.152270 -1.249730 -5.0
# 2013-01-04 -0.248932 -1.722477 -0.572717 -5.0
# 2013-01-05 -0.123981 -0.972887 -1.350000 -5.0
# 2013-01-06 -0.519400 -0.269084 -0.512812 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.648853  5.0  1.0
# 2013-01-02  0.332575 -0.427216 -0.788531  5.0  1.0
# 2013-01-03 -1.663009 -0.152270 -1.249730  5.0  NaN
# 2013-01-04 -0.248932 -1.722477  0.572717  5.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.648853  5.0  1.0
# 2013-01-02  0.332575 -0.427216 -0.788531  5.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.648853  5.0  1.0
# 2013-01-02  0.332575 -0.427216 -0.788531  5.0  1.0
# 2013-01-03 -1.663009 -0.152270 -1.249730  5.0  5.0
# 2013-01-04 -0.248932 -1.722477  0.572717  5.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.329131
# B   -0.590656
# C   -0.212868
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.087787
# 2013-01-02    1.029207
# 2013-01-03    0.483748
# 2013-01-04    0.900327
# 2013-01-05    1.375274
# 2013-01-06    0.924676
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
df.sub(s, axis="index")
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -2.663009 -1.152270 -2.249730  4.0
# 2013-01-04 -3.248932 -4.722477 -2.427283  2.0
# 2013-01-05 -4.876019 -5.972887 -3.650000  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000    0.000000  -65.663963  506.0
# 2013-01-02   33.656543  -43.234217  -79.799333  506.0
# 2013-01-03 -168.296493  -15.409706 -126.472723  506.0
# 2013-01-04  -25.191923 -174.314700   57.958959  506.0
# 2013-01-05   12.546910  -98.456134  136.620019  506.0
# 2013-01-06  -52.563283  -27.231317  -51.896603  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
s.value_counts()
# Out:
# 0    3
# 6    2
# 5    2
# 4    1
# 3    1
# 1    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.909185  0.369681  0.207049 -0.355027
# 1  0.921507  1.164894  0.978399  0.469960
# 2 -0.073976  1.279799  1.681177  1.473598
# 3  1.702537  0.510027  1.216744  0.135825
# 4 -0.415550  0.317990  0.895189  0.394609
# 5  1.143853 -1.476393 -0.162095 -0.958860
# 6 -0.670160 -0.040233  0.564666 -2.452237
# 7 -2.489922  1.689361  1.284681 -0.464311
# 8 -0.785271 -0.215418 -0.430495  1.263208
# 9 -0.645625 -1.035266  1.291319  1.324198

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
right
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

left
right
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['lval'].plot(kind='hist', bins=20, title='lval')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rval'].plot(kind='hist', bins=20, title='rval')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('key').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='lval', y='rval', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['lval']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'lval'}, axis=1)
#               .sort_values('lval', ascending=True))
#   xs = counted['lval']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('lval', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('key')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='key', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('lval')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['rval']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'rval'}, axis=1)
#               .sort_values('rval', ascending=True))
#   xs = counted['rval']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('rval', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('key')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='key', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('rval')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['lval'].plot(kind='line', figsize=(8, 4), title='lval')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['rval'].plot(kind='line', figsize=(8, 4), title='rval')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['key'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='lval', y='key', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['key'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='rval', y='key', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one -1.929343  1.257882
# 1  bar    one  0.112191 -1.225518
# 2  foo    two -0.352154 -0.609697
# 3  bar  three -0.789988 -0.211858
# 4  foo    two -0.570387 -0.934170
# 5  bar    two  1.418538 -1.022110
# 6  foo    one  1.567037 -0.598890
# 7  foo  three -1.023814  0.824431

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  0.740741 -2.459485
# foo -2.308661 -0.060444

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.112191 -1.225518
#     three -0.789988 -0.211858
#     two    1.418538 -1.022110
# foo one   -0.362306  0.658992
#     three -1.023814  0.824431
#     two   -0.922541 -1.543867

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     1.090721 -1.547961
#       two     0.385171 -0.666454
# baz   one    -1.335802  0.463035
#       two    -1.462818 -1.726448

# %%
stacked = df2.stack(future_stack=True)
stacked
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-31b7fa36508b> in <cell line: 1>()
# ----> 1 stacked = df2.stack(future_stack=True)
#       2 stacked
#
# TypeError: DataFrame.stack() got an unexpected keyword argument 'future_stack'

# %%
stacked.unstack()
stacked.unstack(1)
stacked.unstack(0)

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.665389  1.333789
# 1     one  B  foo  0.317165  0.955309
# 2     two  C  foo -0.828525 -0.101310
# 3   three  A  bar -0.204109  1.197292
# 4     one  B  bar -0.971666  1.214710
# 5     one  C  bar -0.334579 -0.950509
# 6     two  A  foo -0.831084  1.347358
# 7   three  B  foo -0.404662 -0.690471
# 8     one  C  foo  1.827673 -0.686672
# 9     one  A  bar  0.384797 -0.258772
# 10    two  B  bar -1.104404 -1.864115
# 11  three  C  bar -0.370395 -0.962909

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.384797 -2.665389
#       B -0.971666  0.317165
#       C -0.334579  1.827673
# three A -0.204109       NaN
#       B       NaN -0.404662
#       C -0.370395       NaN
# two   A       NaN -0.831084
#       B -1.104404       NaN
#       C       NaN -0.828525

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2012-01-01    25203
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.226840
# 2012-03-07    0.475532
# 2012-03-08    1.146650
# 2012-03-09   -1.337600
# 2012-03-10   -0.738272
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-39a5e5de017e> in <cell line: 1>()
# ----> 1 ts_utc.tz_convert("US/Eastern")
#
# NameError: name 'ts_utc' is not defined

# %%
rng
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  1  2  2  4
# 1           1  4  3  3  0  0
# 2           2  2  0  3  4  3
# 3           3  3  3  4  3  2
# 4           4  4  3  4  1  0
# 5           5  3  2  2  1  0
# 6           6  4  0  1  4  4
# 7           7  1  1  2  2  2
# 8           8  3  1  4  3  4
# 9           9  3  3  1  4  1

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  1  1  2  2  4
# 1  4  3  3  0  0
# 2  2  0  3  4  3
# 3  3  3  4  3  2
# 4  4  3  4  1  0
# 5  3  2  2  1  0
# 6  4  0  1  4  4
# 7  1  1  2  2  2
# 8  3  1  4  3  4
# 9  3  3  1  4  1

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  1  2  2  4
# 1           1  4  3  3  0  0
# 2           2  2  0  3  4  3
# 3           3  3  3  4  3  2
# 4           4  4  3  4  1  0
# 5           5  3  2  2  1  0
# 6           6  4  0  1  4  4
# 7           7  1  1  2  2  2
# 8           8  3  1  4  3  4
# 9           9  3  3  1  4  1

# %%
if pd.Series([False, True, False]):
     print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-b27eb9c1dfc0> in <cell line: 1>()
# ----> 1 if pd.Series([False, True, False]):
#       2      print("I was true")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
